# %% [markdown]
# 1.Реализовать генератор пользовательских данных для решения задачи подсчета количества клеток крови на изображениях клеток крови.

# %%
from blood_image_generation import *

# %%
# Генерация датасета
blood_image_generator = BloodImageGenerator()
blood_dataset_generator = BloodDatasetGenerator(blood_image_generator)
images, labels = blood_dataset_generator.generate_dataset()

# %%
# Визуализация
from blood_visualization import *
blood_vis = BloodVisualization()
blood_vis.visualize(images, labels)

# %%
# Генерация и визуализация датасета с раздельным фоном и клетками
images, labels, cells_arr = blood_dataset_generator.generate_dataset_divide_images()
blood_vis.visualize_divided()
